# %%
import pygame

HEIGHT = 600
WIDTH = 600
FPS = 60

WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
RED = (255, 0, 0)
GREEN = (0, 255, 0)
BLUE = (0, 0, 255)

pygame.init()
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Moving ball")
clock = pygame.time.Clock()

ball = pygame.image.load("ball.gif")
ballrect = ball.get_rect()
ballrect.center = WIDTH/2, HEIGHT/2
speed = [2, 3]
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import numpy as np
z = np.load("1.npy")
from matplotlib import pyplot as plt
plt.imshow(z[0])

# %%
# if input image is in range 0..1, please first multiply img by 255
# assume image is ndarray of shape [height, width, channels] where channels can be 1, 3 or 4
import PIL.Image

def zoom(img, zoom):
    w, h = img.size
    zoom2 = zoom * 2
    return img.resize((w*zoom, h*zoom), PIL.Image.NEAREST)


def zoom_at(img, x, y, zoom):
    w, h = img.size
    zoom2 = zoom * 2
    img = img.crop((x - w / zoom2, y - h / zoom2, 
                    x + w / zoom2, y + h / zoom2))
    return img.resize((w, h), Image.LANCZOS)
zoom(PIL.Image.fromarray(z[1000]), 4)
# Out:
# <PIL.Image.Image image mode=RGB size=960x896 at 0x7F090A94B320>

# %%
# print(z[0])

# %%
while 1:
    for event in pygame.event.get():
        if event.type == pygame.QUIT: 
            quit()

    ballrect = ballrect.move(speed)
    if ballrect.left < 0 or ballrect.right > WIDTH:
        speed[0] = -speed[0]
    if ballrect.top < 0 or ballrect.bottom > HEIGHT:
        speed[1] = -speed[1]

    screen.fill(WHITE)
    screen.blit(ball, ballrect)
    pygame.display.flip()
    clock.tick(FPS)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-96ddb35ded30> in <module>()
#      13     screen.blit(ball, ballrect)
#      14     pygame.display.flip()
# ---> 15     clock.tick(FPS)
#
# KeyboardInterrupt:
